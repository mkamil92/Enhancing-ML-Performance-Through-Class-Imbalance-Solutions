# %% [markdown]
# <h1 style="color:blue">Imbalance Technique: Ensemble Methods & Weights</h1>

# %% [markdown]
# # Importing Required Libraries

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import cross_val_predict
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.feature_selection import SelectFromModel

# import library to ignore warnings
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %% [markdown]
# <h1 style="color: red;">Dataset Details</h1>
#   <ul style="list-style-type: none; padding-left: 20px;">
#     <h3><li style="color: green;">Name : IT Customer Chrun</li></h3>
#    <h3><li style="color: green;">URL : https://www.kaggle.com/datasets/soheiltehranipour/it-customer-churn/</li></h3>
#   </ul>

# %%
path = "../Datasets/IT_customer_churn.csv"
data = pd.read_csv(path)
data.head()
data = pd.read_csv(path)
data.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
label = "Churn"

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
# ...

# %% [markdown]
# <h1 style="color:red">Imbanlce Visulaization </h1>

# %%
sns.countplot(x='Churn', data=data)
plt.title('Churn Distribution')
plt.show()

# %% [markdown]
# # Data Cleaning
# ### Handling Duplicates values

# %%
duplicates = data[data.duplicated()]
print(len(duplicates))
data.drop_duplicates(inplace=True, keep="first")
duplicates = data[data.duplicated()]
print(len(duplicates))
# Out:
# 22
# 0

# %% [markdown]
# ## Handling Null Values

# %%
data.isna().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
column = 'TotalCharges'
data[column] = pd.to_numeric(data[column], errors='coerce')

# %%
data.isnull().sum()
# Out:
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %% [markdown]
# <h1 style="color:green">EDA Analysis</h1>

# %%
def EDA(df):
    print("\nSummary Statistics:")
    print(df.describe())

    # Visualize distribution of numerical features
    numerical_features = df.select_dtypes(include=[np.number]).columns
    for feature in numerical_features:
        plt.figure(figsize=(8, 4))
        sns.histplot(df[feature].dropna(), kde=True)
        plt.title(f'Distribution of {feature}')
        plt.show()

    # correlation matrix
    plt.figure(figsize=(12, 6))
    sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
    plt.title('Correlation Matrix')
    plt.show()

# %%
EDA(data)
# Out:
# Summary Statistics:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7021.000000  7021.000000     7021.000000
# mean        0.162512    32.469449       64.851894
# std         0.368947    24.534965       30.069001
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.750000
# 50%         0.000000    29.000000       70.400000
# 75%         0.000000    55.000000       89.900000
# max         1.000000    72.000000      118.750000

# %%
data[column] = data[column].fillna(data[column].mean())

# %%
data.isnull().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# <h1 style="color: blue">Visualize the churn rate based on various categorical features</h1>

# %%
categorical_cols = ['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines',
                    'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
                    'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod']
sns.set_style("darkgrid") 
custom_palette = sns.color_palette("Set2")

for feature in categorical_cols:
    plt.figure(figsize=(10, 6))
    sns.set_palette(custom_palette)
    sns.countplot(x=feature, hue='Churn', data=data)
    plt.title(f'Churn Rate by {feature}')
    plt.xticks(rotation=45)
    plt.legend(title='Churn', loc='upper right')
    plt.show()

# %% [markdown]
# <h1 style="color: blue">Visualize the churn rate based on numerical features</h1>

# %%
# So first of all i ahve to convert 'Churn' column to numeric format
data['Churn'] = data['Churn'].map({'Yes': 1, 'No': 0})
num_features = ['tenure', 'MonthlyCharges', 'TotalCharges']

for feature in num_features:
    plt.figure(figsize=(10, 6))
    sns.boxplot(x='Churn', y=feature, data=data)
    plt.title(f'{feature} Distribution by Churn')
    plt.show()

# %% [markdown]
# # Encoding the Categorical data points

# %%
from sklearn.preprocessing import LabelEncoder
categorical_features = data[data.select_dtypes(include=['object']).columns.tolist()]

def label_encoder(column):
    labels = column.unique()
    label_mapping = {label: i for i, label in enumerate(labels)}
    encoded_column = column.map(label_mapping)
    return encoded_column, label_mapping

for feature in categorical_features:
    encoded_column, label_mapping = label_encoder(data[feature])  
    data[feature] = encoded_column

# %%
data.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              0        0           0       1             0
# 1       1              0        1           0      34             1
# 2       1              0        1           0       2             1
# 3       1              0        1           0      45             0
# 4       0              0        1           0       2             1
#
#    MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 0              0                0               0             0
# 1              1                0               1             1
# 2              1                0               1             0
# 3              0                0               1             1
# 4              1                1               0             1
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 0            0            0                0         0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7021 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7021 non-null   int64
#  1   SeniorCitizen     7021 non-null   int64
#  2   Partner           7021 non-null   int64
#  3   Dependents        7021 non-null   int64
#  4   tenure            7021 non-null   int64
#  5   PhoneService      7021 non-null   int64
#  6   MultipleLines     7021 non-null   int64
#  7   InternetService   7021 non-null   int64
#  8   OnlineSecurity    7021 non-null   int64
#  9   OnlineBackup      7021 non-null   int64
#  10  DeviceProtection  7021 non-null   int64
#  11  TechSupport       7021 non-null   int64
#  12  StreamingTV       7021 non-null   int64
#  13  StreamingMovies   7021 non-null   int64
#  14  Contract          7021 non-null   int64
#  15  PaperlessBilling  7021 non-null   int64
# ...

# %%
sns.heatmap(data.corr(), annot=True,cmap='flare');

# %% [markdown]
# #  Feature Selection Techniques
# <ul style="color:red">
#     <li>Filter Methods</li>
#     <li>Wrapper Methods</li>
#     <li>PCA</li>
#     <ul>

# %%
def filter_methods(X, y):
    # Apply Chi-square Test
    chi2_selector = SelectKBest(chi2, k=10)
    X_chi2 = chi2_selector.fit_transform(X, y)
    
    # Apply Variance Threshold
    vt_selector = VarianceThreshold(threshold=0.1)
    X_vt = vt_selector.fit_transform(X)
    
    # Apply Covariance/Mutual Information
    mi_selector = SelectKBest(mutual_info_classif, k=10)
    X_mi = mi_selector.fit_transform(X, y)
    
    return X_chi2, X_vt, X_mi

# %%
def wrapper_methods(X, y):
    # Apply SelectKBest with chi2 scoring function
    selector = SelectKBest(score_func=chi2, k=10)
    X_selected = selector.fit_transform(X, y)
    return X_selected

# %%
X_chi2, X_vt, X_mi = filter_methods(X_scaled, y)
X_fw = wrapper_methods(X_scaled, y)

# %%
# selecting features  byn using scroes of each features
from sklearn.tree import DecisionTreeClassifier

X = data.drop(columns=[label])
y = data[label]

# Initialize Decision Tree classifier
dt_classifier = DecisionTreeClassifier()

# Train the classifier
dt_classifier.fit(X, y)
# Out:
# DecisionTreeClassifier()

# %%
# Get feature importances
from sklearn.feature_selection import SelectFromModel

feature_importances = dt_classifier.feature_importances_
feature_importances
# Out:
# array([0.02478886, 0.01876639, 0.01791393, 0.0195039 , 0.11757658,
#        0.00167871, 0.01934086, 0.02863785, 0.04509123, 0.01383125,
#        0.01918895, 0.016172  , 0.01032868, 0.01120947, 0.16948052,
#        0.0190229 , 0.03807038, 0.20130505, 0.20809251])

# %%
# Select features based on importance scores
selected_features = SelectFromModel(dt_classifier, threshold=0.05)  # Adjust threshold as needed
selected_features.fit(X, y)
# Out:
# SelectFromModel(estimator=DecisionTreeClassifier(), threshold=0.05)

# %%
# Get selected feature indexes
selected_feature_indices = selected_features.get_support(indices=True)
selected_feature_indices
# Out:
# array([ 4, 14, 17, 18], dtype=int64)

# %%
# # Select the features from the original dataset
selected_X = X.iloc[:, selected_feature_indices]
selected_X.columns
# Out:
# Index(['tenure', 'Contract', 'MonthlyCharges', 'TotalCharges'], dtype='object')

# %%
selected_X.head()
# Out:
#    tenure  Contract  MonthlyCharges  TotalCharges
# 0       1         0           29.85         29.85
# 1      34         1           56.95       1889.50
# 2       2         0           53.85        108.15
# 3      45         1           42.30       1840.75
# 4       2         0           70.70        151.65

# %% [markdown]
# # Data Transformation

# %%
def plot_box(df):
    # Plot boxplots
    plt.figure(figsize=(10, 6))
    sns.boxplot(data=df, orient="v", palette="Set2")
    plt.title("Boxplot of Scaled Features")
    plt.xlabel("Feature Value")
    plt.ylabel("Feature")
    plt.show()

plot_box(selected_X)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# Fit the scaler to the data and transform the data
X_scaled = scaler.fit_transform(selected_X)

# %%
import pandas as pd
df_scaled = pd.DataFrame(X_scaled, columns=selected_X.columns)
plot_box(df_scaled)

# %% [markdown]
# <h1 style="color: blue;">Selected Classifcation Models:</h1>
#   <ol>
#     <h3><li style="color: green;">KNN</li></h3>
#    <h3><li style="color: green;">SVM </li></h3>
#     <h3><li style="color: green;">Naive Bayes</li></h3>
#    <h3><li style="color: green;">Decision Tree</li></h3>
#     <h3><li style="color: green;">Logistic Regression</li></h3>
#   </ol>

# %% [markdown]
# <h1 style="color: blue;">Manual Splitting:</h1>

# %%
from sklearn.model_selection import train_test_split

def get_split(X, y):
    return train_test_split(X, y, test_size=0.2, shuffle=True,random_state=42)
X = X_scaled

# %% [markdown]
# <h1 style="color: indigo;">Function : Confusion matrix</h1>

# %%
def plot_cm(cm):
    # Plot confusion matrix
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
    plt.xlabel('Predicted labels')
    plt.ylabel('True labels')
    plt.title('Confusion Matrix')
    plt.show()

# %% [markdown]
# <h1 style="color: indigo;">Function: Classification Report & Confusion Matric</h1>

# %%
import numpy as np
import seaborn as sns
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix, classification_report

def train_test_visualize(model, X, y, cv=5):
    y_pred = cross_val_predict(model, X, y, cv=cv)

    cm = confusion_matrix(y, y_pred)
    plot_cm(cm)
    # Generate classification report
    report = classification_report(y, y_pred, zero_division=1)
    print("Classification Report:\n", report)

# %% [markdown]
# <h1 style="color: Red;">Baseline Execution</h1>

# %% [markdown]
# <h2 style="color: blue;">1- KNN</h2>

# %%
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

def plot_knn(X, y):
  # Define a list of k values to try
  k_values = range(1, 30, 2)

  # Train KNN classifiers with different k values
  scores = list()
  for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    score = knn.score(X_test, y_test)
    scores.append(score)

  plt.plot(k_values, scores)
  plt.title("Best Value For k")
  plt.xlabel('K')
  plt.ylabel("Accuracy")
  plt.tight_layout()
  plt.show()

  return k_values[scores.index(max(scores))]
k = plot_knn(X, y)

# %%
def run_knn(X, y):
  knn = KNeighborsClassifier(n_neighbors=k)
  train_test_visualize(knn, X, y)

run_knn(X, y)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.90      0.86      5164
#            1       0.63      0.48      0.54      1857
#
#     accuracy                           0.79      7021
#    macro avg       0.73      0.69      0.70      7021
# weighted avg       0.77      0.79      0.78      7021

# %% [markdown]
# <h2 style="color: blue;">2- Logistic Regression</h2>

# %%
from sklearn.linear_model import LogisticRegression

def run_lr(X, y):
  lr = LogisticRegression(max_iter=500)
  train_test_visualize(lr, X, y)

run_lr(X, y)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.90      0.86      5164
#            1       0.63      0.49      0.55      1857
#
#     accuracy                           0.79      7021
#    macro avg       0.73      0.69      0.71      7021
# weighted avg       0.78      0.79      0.78      7021

# %% [markdown]
# <h2 style="color: blue;">3- Decision Tree Classifier</h2>

# %%
from sklearn.tree import DecisionTreeClassifier

def run_tree(X, y):
  tree_model = DecisionTreeClassifier()
  train_test_visualize(tree_model, X, y)

run_tree(X, y)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.81      0.81      5164
#            1       0.48      0.48      0.48      1857
#
#     accuracy                           0.72      7021
#    macro avg       0.64      0.65      0.65      7021
# weighted avg       0.72      0.72      0.72      7021

# %% [markdown]
# <h2 style="color: blue;">4- SVM</h2>

# %%
from sklearn.svm import SVC

def run_svm(X, y):
  # Initialize SVM classifier
  svm_model = SVC(kernel='linear')

  train_test_visualize(svm_model, X, y)

run_svm(X, y)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.88      0.86      5164
#            1       0.61      0.50      0.55      1857
#
#     accuracy                           0.78      7021
#    macro avg       0.72      0.69      0.70      7021
# weighted avg       0.77      0.78      0.78      7021

# %% [markdown]
# <h2 style="color: blue;">5- Naive Bayes</h2>

# %%
from sklearn.naive_bayes import GaussianNB

def run_nb(X, y):
    nb_classifier = GaussianNB()
    train_test_visualize(nb_classifier, X, y)

run_nb(X, y)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.68      0.77      5164
#            1       0.47      0.78      0.58      1857
#
#     accuracy                           0.70      7021
#    macro avg       0.68      0.73      0.68      7021
# weighted avg       0.78      0.70      0.72      7021

# %% [markdown]
# <h1 style="color: red;">Class Imbalance Technique</h1>
# <h2 style="color: blue;">Ensemble Methods and Weights</h2>

# %%
import numpy as np

def calculate_class_weights(y):
    unique_classes, class_counts = np.unique(y, return_counts=True)
    total_samples = len(y)
    class_weights = {}

    for class_label, class_count in zip(unique_classes, class_counts):
        class_weight = total_samples / (2.0 * class_count)
        class_weights[class_label] = class_weight

    return class_weights

# Assuming 'y' contains the class labels (0s and 1s) for the binary classification problem
class_weights = calculate_class_weights(y)

# %% [markdown]
# <h2 style="color: blue;">1- Logistic Regression</h2>

# %%
from sklearn.linear_model import LogisticRegression

# Assuming you have calculated class_weights
logreg = LogisticRegression(class_weight=class_weights)
train_test_visualize(logreg, X, y)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.68      0.78      5164
#            1       0.48      0.83      0.61      1857
#
#     accuracy                           0.72      7021
#    macro avg       0.70      0.76      0.70      7021
# weighted avg       0.80      0.72      0.74      7021

# %% [markdown]
# <h2 style="color: blue;">2- SVM</h2>

# %%
from sklearn.svm import SVC

svm_model = SVC(kernel='linear', class_weight=class_weights)
train_test_visualize(svm_model, X, y)

# %% [markdown]
# <h2 style="color: blue;">3- Gradient Boosting based on Histograms</h2>

# %%
from sklearn.ensemble import GradientBoostingClassifier

clf = GradientBoostingClassifier(n_estimators=50)
train_test_visualize(clf, X, y)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.90      0.86      5164
#            1       0.64      0.48      0.55      1857
#
#     accuracy                           0.79      7021
#    macro avg       0.73      0.69      0.71      7021
# weighted avg       0.78      0.79      0.78      7021

# %% [markdown]
# <h2 style="color: blue;">4- Random Forest</h2>

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(n_estimators=50, random_state=42, class_weight=class_weights)
train_test_visualize(clf, X, y)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.87      0.85      5164
#            1       0.57      0.48      0.52      1857
#
#     accuracy                           0.77      7021
#    macro avg       0.70      0.67      0.68      7021
# weighted avg       0.76      0.77      0.76      7021

# %% [markdown]
# <h2 style="color: blue;">5- AdaBoost Classifier</h2>

# %%
from sklearn.ensemble import AdaBoostClassifier

clf = AdaBoostClassifier(n_estimators=50, random_state=42, algorithm="SAMME")
train_test_visualize(clf, X, y)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.91      0.86      5164
#            1       0.64      0.43      0.52      1857
#
#     accuracy                           0.79      7021
#    macro avg       0.73      0.67      0.69      7021
# weighted avg       0.77      0.79      0.77      7021

# %% [markdown]
# <h2 style="color: blue;">6-Balanced Random Forest Classifier</h2>

# %%
from imblearn.ensemble import BalancedRandomForestClassifier

model = BalancedRandomForestClassifier(n_estimators=100, random_state=42, sampling_strategy='all', 
                                           replacement=False, bootstrap=True, class_weight=class_weights)
train_test_visualize(model, X, y)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.72      0.79      5164
#            1       0.49      0.75      0.59      1857
#
#     accuracy                           0.73      7021
#    macro avg       0.69      0.73      0.69      7021
# weighted avg       0.78      0.73      0.74      7021

# %% [markdown]
# ### Easy Ensemble Classifier

# %%
from imblearn.ensemble import EasyEnsembleClassifier

model = EasyEnsembleClassifier(n_estimators=100, random_state=42)
train_test_visualize(model, X, y)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.71      0.80      5164
#            1       0.50      0.80      0.61      1857
#
#     accuracy                           0.73      7021
#    macro avg       0.70      0.76      0.71      7021
# weighted avg       0.80      0.73      0.75      7021

# %% [markdown]
# <h1 style="color: blue;">Conclusion</h1>

# %% [markdown]
#  <h3 style="color:green"> -> After applying ensemble methods and weighted techniques to the dataset several improvements in the classification performance are observed like Logistic Regression shows enhanced precision, recall, and f1-score for both classes indicating better predictions for customer churn. The gradient-based method and random forest also demonstrate improved performance compared to the initial models, particularly in their ability to predict class 1 which is churn . <br><br>
#     -> The AdaBoost and Balanced Random Forest models show mixed results, with improvements in some metrics but not in others. The Easy Ensemble Classifier stands out with significant improvements in recall for both classes, indicating better overall predictive performance.<br><br>
#     -> these techniques have helped enhance the models' abilities to predict customer churn </h3>
