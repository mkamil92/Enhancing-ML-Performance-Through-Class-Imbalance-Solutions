# %% [markdown]
# # Importing Required Libraries

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import cross_val_predict
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.feature_selection import SelectFromModel

# import library to ignore warnings
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %% [markdown]
# <h1 style="color: red;">Dataset Details</h1>
#   <ul style="list-style-type: none; padding-left: 20px;">
#     <h3><li style="color: green;">Name : Credit-card-Fraud Detection-Imbalanced-Dataset</li></h3>
#    <h3><li style="color: green;">URL : https://www.kaggle.com/datasets/dark06thunder/credit-card-dataset</li></h3>
#   </ul>

# %% [markdown]
# # Reading dataset

# %%
path = "../Datasets/credit_dataset.csv"
data = pd.read_csv(path)
data.head()
# Out:
#    Unnamed: 0       ID GENDER CAR REALITY  NO_OF_CHILD    INCOME  \
# 0           0  5008806      M   Y       Y            0  112500.0
# 1           1  5008808      F   N       Y            0  270000.0
# 2           2  5008809      F   N       Y            0  270000.0
# 3           3  5008810      F   N       Y            0  270000.0
# 4           4  5008811      F   N       Y            0  270000.0
#
#             INCOME_TYPE                 EDUCATION_TYPE           FAMILY_TYPE  \
# 0               Working  Secondary / secondary special               Married
# 1  Commercial associate  Secondary / secondary special  Single / not married
# 2  Commercial associate  Secondary / secondary special  Single / not married
# 3  Commercial associate  Secondary / secondary special  Single / not married
# 4  Commercial associate  Secondary / secondary special  Single / not married
#
#           HOUSE_TYPE  FLAG_MOBIL  WORK_PHONE  PHONE  E_MAIL  FAMILY SIZE  \
# ...

# %%
# imbalance
target_counts = data['TARGET'].value_counts()
plt.figure(figsize=(6, 4))
plt.bar(target_counts.index, target_counts.values, color=['blue', 'red'])
plt.xticks(target_counts.index, ['No Fraud', 'Fraud'])
plt.xlabel('Class')
plt.ylabel('Count')
plt.title('Distribution of Classes')
plt.show()

# %% [markdown]
# <h2 style="color:green">From the above plot we can see that the dataset is highly imbalanced with only few of target class(FRAUD</h2>

# %%
label = "TARGET"
data.drop(columns=["ID", "Unnamed: 0"], inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25134 entries, 0 to 25133
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   GENDER          25134 non-null  object
#  1   CAR             25134 non-null  object
#  2   REALITY         25134 non-null  object
#  3   NO_OF_CHILD     25134 non-null  int64
#  4   INCOME          25134 non-null  float64
#  5   INCOME_TYPE     25134 non-null  object
#  6   EDUCATION_TYPE  25134 non-null  object
#  7   FAMILY_TYPE     25134 non-null  object
#  8   HOUSE_TYPE      25134 non-null  object
#  9   FLAG_MOBIL      25134 non-null  int64
#  10  WORK_PHONE      25134 non-null  int64
#  11  PHONE           25134 non-null  int64
#  12  E_MAIL          25134 non-null  int64
#  13  FAMILY SIZE     25134 non-null  float64
#  14  BEGIN_MONTH     25134 non-null  int64
#  15  AGE             25134 non-null  int64
#  16  YEARS_EMPLOYED  25134 non-null  int64
# ...

# %% [markdown]
# # Data Cleaning

# %%
duplicates = data[data.duplicated()]
print(len(duplicates))
data.drop_duplicates(inplace=True, keep="first")
duplicates = data[data.duplicated()]
print(len(duplicates))
# Out:
# 2938
# 0

# %% [markdown]
# ## Handling Null Values

# %%
data.isna().sum()
# Out:
# GENDER            0
# CAR               0
# REALITY           0
# NO_OF_CHILD       0
# INCOME            0
# INCOME_TYPE       0
# EDUCATION_TYPE    0
# FAMILY_TYPE       0
# HOUSE_TYPE        0
# FLAG_MOBIL        0
# WORK_PHONE        0
# PHONE             0
# E_MAIL            0
# FAMILY SIZE       0
# BEGIN_MONTH       0
# AGE               0
# YEARS_EMPLOYED    0
# TARGET            0
# dtype: int64

# %% [markdown]
# # EDA Function

# %%
def EDA(df):
    print("\nSummary Statistics:")
    print(df.describe())

    # Visualize distribution of numerical features
    numerical_features = df.select_dtypes(include=[np.number]).columns
    for feature in numerical_features:
        plt.figure(figsize=(8, 4))
        sns.histplot(df[feature].dropna(), kde=True)
        plt.title(f'Distribution of {feature}')
        plt.show()

    # correlation matrix
    plt.figure(figsize=(12, 6))
    sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
    plt.title('Correlation Matrix')
    plt.show()

# %%
EDA(data)
# Out:
# Summary Statistics:
#         NO_OF_CHILD        INCOME  FLAG_MOBIL    WORK_PHONE         PHONE  \
# count  22196.000000  2.219600e+04     22196.0  22196.000000  22196.000000
# mean       0.514147  1.938834e+05         1.0      0.274148      0.292215
# std        0.792126  1.032757e+05         0.0      0.446094      0.454791
# min        0.000000  2.700000e+04         1.0      0.000000      0.000000
# 25%        0.000000  1.350000e+05         1.0      0.000000      0.000000
# 50%        0.000000  1.800000e+05         1.0      0.000000      0.000000
# 75%        1.000000  2.250000e+05         1.0      1.000000      1.000000
# max       19.000000  1.575000e+06         1.0      1.000000      1.000000
#
#              E_MAIL   FAMILY SIZE   BEGIN_MONTH           AGE  YEARS_EMPLOYED  \
# count  22196.000000  22196.000000  22196.000000  22196.000000    22196.000000
# mean       0.100964      2.295774     25.988151     40.515048        7.189043
# ...

# %% [markdown]
# <h1 style="color:green">Correlation Results</h1>
# <p>A correlation of 1 means a strong positive relationship while -1 means a strong negative relationship but here in given heatmap i haven't seen any significant value so in order to get imortant features i select feautres by using classifier below.</p>

# %% [markdown]
# # Encoding the Categorical data points

# %%
# as we see that our dataset have cateforical data so we have to encode it
categorical_features = data[data.select_dtypes(include=['object']).columns.tolist()]
label_encoder = LabelEncoder()

for feature in categorical_features:
    data.loc[:, feature] = label_encoder.fit_transform(data[feature])

# %%
data.head()
# all columns are in numeric form now
# Out:
#    GENDER  CAR  REALITY  NO_OF_CHILD    INCOME  INCOME_TYPE  EDUCATION_TYPE  \
# 0       1    1        1            0  112500.0            4               4
# 1       0    0        1            0  270000.0            0               4
# 2       0    0        1            0  270000.0            0               4
# 4       0    0        1            0  270000.0            0               4
# 5       1    1        1            0  270000.0            4               1
#
#    FAMILY_TYPE  HOUSE_TYPE  FLAG_MOBIL  WORK_PHONE  PHONE  E_MAIL  \
# 0            1           1           1           0      0       0
# 1            3           1           1           0      1       1
# 2            3           1           1           0      1       1
# 4            3           1           1           0      1       1
# 5            1           1           1           1      1       1
#
#    FAMILY SIZE  BEGIN_MONTH  AGE  YEARS_EMPLOYED  TARGET
# ...

# %% [markdown]
# # Feature Importance and Feature Selection

# %%
# here i have write code in order to extract meaningful features from my dataset and for that i am getting help from decision classifier that will give me score and based on that score i will choose my features that i will use in my models
X = data.drop(columns=[label])
y = data[label]

# Initialize Decision Tree classifier
dt_classifier = DecisionTreeClassifier()

# Train the classifier
dt_classifier.fit(X, y)
# Out:
# DecisionTreeClassifier()

# %%
# Get feature importances by their scores
feature_importances = dt_classifier.feature_importances_
feature_importances
# Out:
# array([0.01811181, 0.04740983, 0.02525056, 0.01579527, 0.13714412,
#        0.04784551, 0.02857393, 0.05354573, 0.0234941 , 0.        ,
#        0.01521825, 0.02750258, 0.01671005, 0.03782678, 0.26341053,
#        0.13625174, 0.10590921])

# %%
# Select features based on importance scores
selected_features = SelectFromModel(dt_classifier, threshold=0.05)  # Adjust threshold as needed
selected_features.fit(X, y)
# Out:
# SelectFromModel(estimator=DecisionTreeClassifier(), threshold=0.05)

# %%
# now here i am seelecting features based on importance scores
selected_feature_indices = selected_features.get_support(indices=True)
selected_feature_indices
# Out:
# array([ 4,  5, 14, 15, 16], dtype=int64)

# %%
# Now as i identify importance features now i will get them from my dataset
selected_X = X.iloc[:, selected_feature_indices]
selected_X.columns
# Out:
# Index(['INCOME', 'INCOME_TYPE', 'BEGIN_MONTH', 'AGE', 'YEARS_EMPLOYED'], dtype='object')

# %%
selected_X.head()
# Out:
#      INCOME  INCOME_TYPE  BEGIN_MONTH  AGE  YEARS_EMPLOYED
# 0  112500.0            4           29   59               3
# 1  270000.0            0            4   52               8
# 2  270000.0            0           26   52               8
# 4  270000.0            0           38   52               8
# 5  270000.0            4            5   46               2

# %% [markdown]
# # Data Transformation

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def plot_box(df):
    # Plot boxplots
    plt.figure(figsize=(10, 6))
    sns.boxplot(data=df, orient="v", palette="Set2")
    plt.title("Boxplot of Scaled Features")
    plt.xlabel("Feature Value")
    plt.ylabel("Feature")
    plt.show()

plot_box(selected_X)
# as per features boxplots we can see that we need to perforn transformation

# %%
scaler = StandardScaler()

# Fit the scaler to the data and transform the data
X_scaled = scaler.fit_transform(selected_X)

# %%
df_scaled = pd.DataFrame(X_scaled, columns=selected_X.columns)
plot_box(df_scaled)

# %% [markdown]
# # Different classification Models

# %% [markdown]
# <h1 style="color: blue;">Selected Classifcation Models:</h1>
#   <ol>
#     <h3><li style="color: green;">KNN</li></h3>
#    <h3><li style="color: green;">SVM </li></h3>
#     <h3><li style="color: green;">Naive Bayes</li></h3>
#    <h3><li style="color: green;">Decision Tree</li></h3>
#     <h3><li style="color: green;">Logistic Regression</li></h3>
#   </ol>

# %% [markdown]
# # Modeling

# %%
#Here i make a fucntionn for splitting data in train test
def get_split(X, y):
    return train_test_split(X, y, test_size=0.2, shuffle=True,random_state=42)
X = X_scaled

# %% [markdown]
# <h1 style="color: indigo;">Confusion matrix Function</h1>
# <h4>As i have to use it again and again for all the models so i make a function of confusion matrix having name plot_cm </h4>

# %%
def plot_cm(cm):
    # Plot confusion matrix
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
    plt.xlabel('Predicted labels')
    plt.ylabel('True labels')
    plt.title('Confusion Matrix')
    plt.show()

# %% [markdown]
# <h1 style="color: indigo;">Function: Classification Report & Confusion Matric</h1>

# %%
def train_test_visualize(model, X, y):
    y_pred = cross_val_predict(model, X, y, cv=5)
    cm = confusion_matrix(y, y_pred)
    plot_cm(cm)
    # Generate classification report
    report = classification_report(y, y_pred, zero_division=1)
    print("Classification Report:\n", report)

# %% [markdown]
# <h1 style="color: Red;">Baseline Execution</h1>

# %% [markdown]
# <h2 style="color: blue;">1- KNN</h2>

# %%
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

def plot_knn(X, y):
  # Define a list of k values to try
  k_values = range(1, 30, 2)

  # Train KNN classifiers with different k values
  scores = list()
  for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)
    y_pred = cross_val_predict(knn, X, y, cv=5)
    score = accuracy_score(y, y_pred)
    scores.append(score)

  plt.plot(k_values, scores)
  plt.title("Best Value For k")
  plt.xlabel('K')
  plt.ylabel("Accuracy")
  plt.tight_layout()
  plt.show()

  return k_values[scores.index(max(scores))]
k = plot_knn(X, y)

# %%
def run_knn(X, y):
  knn = KNeighborsClassifier(n_neighbors=k)
  train_test_visualize(knn, X, y)

run_knn(X, y)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99     21788
#            1       1.00      0.00      0.00       408
#
#     accuracy                           0.98     22196
#    macro avg       0.99      0.50      0.50     22196
# weighted avg       0.98      0.98      0.97     22196

# %% [markdown]
# <h2 style="color: blue;">2- Logistic Regression</h2>

# %%
def run_lr(X, y):
  lr = LogisticRegression(max_iter=500)
  train_test_visualize(lr, X, y)

run_lr(X, y)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99     21788
#            1       1.00      0.00      0.00       408
#
#     accuracy                           0.98     22196
#    macro avg       0.99      0.50      0.50     22196
# weighted avg       0.98      0.98      0.97     22196

# %% [markdown]
# <h2 style="color: blue;">3- Decision Tree Classifier</h2>

# %%
def run_tree(X, y):
  tree_model = DecisionTreeClassifier()
  train_test_visualize(tree_model, X, y)

run_tree(X, y)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98     21788
#            1       0.04      0.07      0.05       408
#
#     accuracy                           0.96     22196
#    macro avg       0.51      0.52      0.52     22196
# weighted avg       0.97      0.96      0.96     22196

# %% [markdown]
# <h2 style="color: blue;">4- SVM</h2>

# %%
def run_svm(X, y):
  # Initialize SVM classifier
  svm_model = SVC(kernel='linear')

  train_test_visualize(svm_model, X, y)

run_svm(X, y)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99     21788
#            1       1.00      0.00      0.00       408
#
#     accuracy                           0.98     22196
#    macro avg       0.99      0.50      0.50     22196
# weighted avg       0.98      0.98      0.97     22196

# %% [markdown]
# <h2 style="color: blue;">5- Naive Bayes</h2>

# %%
def run_nb(X, y):
    nb_classifier = GaussianNB()
    train_test_visualize(nb_classifier, X, y)

run_nb(X, y)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99     21788
#            1       0.00      0.00      0.00       408
#
#     accuracy                           0.98     22196
#    macro avg       0.49      0.50      0.50     22196
# weighted avg       0.96      0.98      0.97     22196

# %% [markdown]
# <h1 style="color: red;">Class Imbalance Technique</h1>
# <h2 style="color: blue;">Clustering Based Sampling</h2>

# %%
# !pip install imbalanced-learn
from imblearn.over_sampling import SMOTE

sm = SMOTE(random_state=42, sampling_strategy='auto', k_neighbors=k)
X, y = sm.fit_resample(X, y)

# %% [markdown]
# <h2 style="color:red">As i have make functions of each model before class imbalance techniques so now  after applying class imbalance techniques i am just calling to existing functions and comparing results before anb after class imbalance techniques</h2>

# %% [markdown]
# <h2 style="color: blue;">1- KNN</h2>

# %%
run_knn(X, y)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.75      0.83     21788
#            1       0.79      0.95      0.86     21788
#
#     accuracy                           0.85     43576
#    macro avg       0.86      0.85      0.85     43576
# weighted avg       0.86      0.85      0.85     43576

# %% [markdown]
# <h2 style="color: blue;">2- Logistic Regression</h2>

# %%
run_lr(X, y)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.63      0.62      0.62     21788
#            1       0.63      0.63      0.63     21788
#
#     accuracy                           0.63     43576
#    macro avg       0.63      0.63      0.63     43576
# weighted avg       0.63      0.63      0.63     43576

# %% [markdown]
# <h2 style="color: blue;">3- Decision Tree</h2>

# %%
run_tree(X, y)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95     21788
#            1       0.94      0.97      0.95     21788
#
#     accuracy                           0.95     43576
#    macro avg       0.95      0.95      0.95     43576
# weighted avg       0.95      0.95      0.95     43576

# %% [markdown]
# <h2 style="color: blue;">4- SVM</h2>

# %%
run_svm(X, y)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.63      0.61      0.62     21788
#            1       0.62      0.64      0.63     21788
#
#     accuracy                           0.63     43576
#    macro avg       0.63      0.63      0.63     43576
# weighted avg       0.63      0.63      0.63     43576

# %% [markdown]
# <h2 style="color: blue;">5- Naive Bayes</h2>

# %%
run_nb(X, y)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.65      0.52      0.58     21788
#            1       0.60      0.72      0.65     21788
#
#     accuracy                           0.62     43576
#    macro avg       0.62      0.62      0.62     43576
# weighted avg       0.62      0.62      0.62     43576

# %% [markdown]
# <h1 style="color: blue;">Conclusion</h1>

# %% [markdown]
# <h2 style="color:blue">As per results of classification algorithms i can conclude overall results of each alogorithm like:<h2>
# <h3 style="color:green">Before applying clustering smote technique,KNN had high precision but low recall for the minority class but after applying clustering smote technique, both precision and recall improved significantly, resulting in a balanced F1-score for both classes.</h3>
#     <h3 style="color:green">Logistic regression showed a significant improvement in both precision and recall for the minority class after applying clustering smote technique. However the overall performance is moderate compared to other models</h3>
#     <h3 style="color:green">Before imbalance technique the decision tree had low recall for the minority class. After applying imbalance technique both precision and recall improved drastically, resulting in a balanced F1-score for both classes</h3>
#     <h3 style="color:green">SVM exhibited similar behavior to logistic regression with a moderate performance improvement after imbalance techniques, but still not as balanced as other algorithms.</h3>
#     <h3 style="color:green">Naive Bayes had a low recall for the minority class before applying imbalance techniques but smote technique there was an improvement in recall, but precision decreased that's indicating a trade-off between precision and recall.</h3>

# %% [markdown]
# <h2 style="color:red">So for this credit card fraud detection dataset, the decision tree algorithm performed the best after applying class imbalance techniques, with balanced precision, recall, and F1-score for both classes. </h2>
